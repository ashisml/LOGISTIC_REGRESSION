# %%
import numpy as np
import keras
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# %matplotlib inline
# Out:
# C:\Users\Ad\Anaconda3\envs\newenvt\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
n_pts = 500
np.random.seed(0)
Xa = np.array([np.random.normal(13, 2, n_pts),
               np.random.normal(12, 2, n_pts)]).T
Xb = np.array([np.random.normal(8, 2, n_pts),
               np.random.normal(6, 2, n_pts)]).T
 
X = np.vstack((Xa, Xb))
y = np.matrix(np.append(np.zeros(n_pts), np.ones(n_pts))).T
 
plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])

# %%
model = Sequential()
model.add(Dense(units=1, input_shape=(2,), activation='sigmoid'))
adam=Adam(lr = 0.1 )
model.compile(adam, loss='binary_crossentropy', metrics=['accuracy'])
h=model.fit(x=X, y=y, verbose=1, batch_size=50,epochs=500, shuffle='true')
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 2s 2ms/step - loss: 1.4936 - accuracy: 0.5370
# Epoch 2/500
# 1000/1000 [==============================] - 0s 68us/step - loss: 0.6487 - accuracy: 0.5980
# Epoch 3/500
# 1000/1000 [==============================] - 0s 64us/step - loss: 0.4448 - accuracy: 0.8490
# Epoch 4/500
# 1000/1000 [==============================] - 0s 76us/step - loss: 0.3875 - accuracy: 0.8950
# Epoch 5/500
# 1000/1000 [==============================] - 0s 72us/step - loss: 0.3441 - accuracy: 0.9050
# Epoch 6/500
# 1000/1000 [==============================] - 0s 70us/step - loss: 0.3112 - accuracy: 0.9240
# Epoch 7/500
# 1000/1000 [==============================] - 0s 71us/step - loss: 0.2919 - accuracy: 0.9310
# Epoch 8/500
# 1000/1000 [==============================] - 0s 70us/step - loss: 0.2641 - accuracy: 0.9390
# Epoch 9/500
# 1000/1000 [==============================] - 0s 85us/step - loss: 0.2375 - accuracy: 0.9580
# Epoch 10/500
# ...

# %%
plt.plot(h.history['accuracy'])
 
plt.legend(['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
# Out:
# Text(0.5,0,'epoch')

# %%
plt.plot(h.history['loss'])
plt.legend(['loss'])
plt.title('loss')
plt.xlabel('epoch')
# Out:
# Text(0.5,0,'epoch')

# %%
def plot_decision_boundary(X, y, model):
    
    #specifying horizontal span of data
    x_span = np.linspace(min(X[:,0]) - 1, max(X[:,0]) + 1)  #(min(X[:,0]) specifies minimum vales from 1st column of X
    
    #specifu=ying vertical span of data
    y_span = np.linspace(min(X[:,1]) - 1, max(X[:,1]) + 1)  #(min(X[:,1]) specifies minimum vales from 2nd column of X
   
    #The purpose of meshgrid is to create a rectangular grid out ofan array of x values and an array of y values 

    xx, yy = np.meshgrid(x_span, y_span) 
    #xx will have 500*500 matrix , where the remmimg 499 rows are copy of 1st row of x_span
    #yy will have 500*500 matrix , where the remmimg 499 rows are copy of 1st row of y_span
    xx_, yy_ = xx.ravel(), yy.ravel()
    grid = np.c_[xx_, yy_] #to concatenate the arrays columnwise 
    
    pred_func = model.predict(grid) # we are now predicting for all vlues in grid 
    z = pred_func.reshape(xx.shape)
    plt.contourf(xx, yy, z)

# %%
#Testing meshgrid

import numpy as np

#specifying horizontal span of data
x_span = np.linspace(min(X[:,0]) - 1, max(X[:,0]) + 1)  #(min(X[:,0]) specifies minimum vales from 1st column of X
    
#specifu=ying vertical span of data
y_span = np.linspace(min(X[:,1]) - 1, max(X[:,1]) + 1)  #(min(X[:,1]) specifies minimum vales from 2nd column of X

xx, yy = np.meshgrid(x_span, y_span)
plt.plot(xx,yy,marker='.',color='k',linestyle='none')

# %%
plot_decision_boundary(X, y, model)

# %%
plot_decision_boundary(X, y, model)
plt.scatter(X[:n_pts,0], X[:n_pts,1]) # to print first n_pts ,whreren_pts=500
plt.scatter(X[n_pts:,0], X[n_pts:,1]) # to print all points from n_pts that is from 501

# %% [markdown]
# # predicting for a single choosen random point

# %%
#predicting for a single choosen random point 

plot_decision_boundary(X, y, model)

plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])


x = 7.5
y = 5
 
 
point = np.array([[x, y]])
prediction = model.predict(point)
plt.plot([x], [y], marker='o', markersize=10, color="red")
print("prediction is: ",prediction)
# Out:
# prediction is:  [[0.9999856]]
